# %%
import pandas as pd

# %%
houses = pd.read_csv("data/kc_house_data.csv")

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
unique_value = houses["floors"].unique

# %%
unique_value
# Out:
# <bound method Series.unique of 0        1.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 21608    3.0
# 21609    2.0
# 21610    2.0
# 21611    2.0
# 21612    2.0
# Name: floors, Length: 21613, dtype: float64>

# %%
netflix = pd.read_csv("data/netflix_titles.csv", sep = "|")

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
u = netflix["rating"].unique()

# %%
u
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
u = houses["floors"].nunique()

# %%
u
# Out:
# 6

# %%
nlargest_rooms = (houses["price"].nlargest(2))

# %%
nlargest_rooms
# Out:
# 7252    7700000.0
# 3914    7062500.0
# Name: price, dtype: float64

# %%
houses.nlargest(2, ["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6        8.0
# 3914  9808700762  20140611T000000  7062500.0         5        4.5
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
# 3914           2360      1940          2001    98004  47.6500 -122.214
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
# 3914           3930       25449
#
# [2 rows x 21 columns]

# %%
houses["bedrooms"].value_counts(ascending = True)
# Out:
# 11       1
# 33       1
# 10       3
# 9        6
# 0       13
# 8       13
# 7       38
# 1      199
# 6      272
# 5     1601
# 2     2760
# 4     6882
# 3     9824
# Name: bedrooms, dtype: int64

# %%
houses[["view", "waterfront"]].value_counts()
# Out:
# view  waterfront
# 0     0             19489
# 2     0               955
# 3     0               491
# 1     0               331
# 4     0               184
#       1               135
# 3     1                19
# 2     1                 8
# 1     1                 1
# dtype: int64

# %%
houses[["bedrooms", "bathrooms", "grade","view"]].value_counts().plot()
# Out:
# <Axes: xlabel='bedrooms,bathrooms,grade,view'>

# %%
houses["bedrooms"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
netflix[["title", "rating"]].value_counts().plot(kind = "bar", x = "rating", y = "title")

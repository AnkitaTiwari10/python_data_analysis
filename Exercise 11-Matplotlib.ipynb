# %%
import matplotlib.pyplot as plt

# %%
avg_sp500_close = [
    1427.22,
    1192.57,
    993.93,
    965.23,
    1130.65,
    1207.23,
    1310.46,
    1477.18,
    1220.04,
    948.05,
    1139.97,
    1267.64,
    1379.61,
    1643.80,
    1931.38,
    2061.07,
    2094.65,
    2449.08,
    2746.21,
    2913.36,
    3217.86,
    4246.11
]

avg_nasdaq_close = [
    3783.67,
    2029.61,
    1539.73,
    1647.17,
    1986.53,
    2099.32,
    2263.41,
    2578.47,
    2161.68,
    1845.39,
    2349.89,
    2677.44,
    2965.74,
    3541.29,
    4375.10,
    4945.55,
    4987.79,
    6235.30,
    7425.96,
    7940.36,
    10201.51,
    14294.87
]

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]

# %%
plt.style.use("fivethirtyeight")
plt.title("AVG Annual Close By Year")
plt.plot(years,avg_sp500_close, label="S & P 500",color = "Blue")
plt.plot(years,avg_nasdaq_close, label="NASDAQ", color="Red")
plt.legend()
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.figure(figsize=(8,6), dpi=200)
resorts = ["Crested Butte", "Aspen", "Telluride", "Wolf Creek"]
snow_last_24 = [29,15,15,23]
snow_next_24 = [16,6,19,30]

# %%
plt.bar(resorts,snow_next_24,color="#74b9ff",label="Next 24 hours")
plt.bar(resorts,snow_last_24,color="#7ed6df",label="Last 24 hours")
plt.legend(loc="upper left")
plt.ylabel("Inches")
plt.title("CO Snow Storm Report")
# Out:
# Text(0.5, 1.0, 'CO Snow Storm Report')

# %%
labels = [
    "Building Construction", 
    "Deferred Maintenance",
    "General Contractor Fees",
    "Owner Costs",
    "Site Construction"
]
costs = [
    47945975,
    3753584,
    7340612,
    18247137,
    5766685
]
colors = ["#355070", "#6d597a", "#b56576", "#e56b6f", "#eaac8b"]

# %%
plt.pie(costs,
        labels=labels,
        explode = (0,0.1,0,0,0.1), 
        colors=colors,
       autopct = "%.0f%%")
plt.title("School District Cost Breakdown")
# Out:
# Text(0.5, 1.0, 'School District Cost Breakdown')

# %%
import pandas as pd
house = pd.read_csv("data/kc_house_data.csv", parse_dates=["date"])
house["Week Day"] =house["date"].dt.day_name().value_counts()

# %%
house
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# ...

# %%
nums = np.arange(5)
plt.figure(figsize=(10,6))
plt.suptitle("Multiples", fontsize = 30, c="Red")
plt.subplot(1,3,1)
plt.plot(nums*3)
plt.title("Cubed")
plt.subplot(1,3,2)
plt.plot(nums)
plt.title("x")
plt.subplot(1,3,3)
plt.plot(nums**10)
plt.title("10 times")
plt.tight_layout()

# %%
nums = np.arange(5)
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(nums)
plt.subplot(2,2,2)
plt.plot(nums**2)
plt.subplot(2,2,3)
plt.plot(nums**4)
plt.subplot(2,2,4)
plt.plot(nums**8)
plt.suptitle("SUBPLOTTING")
# Out:
# Text(0.5, 0.98, 'SUBPLOTTING')

# %%
import pandas as pd
coin = pd.read_csv("data/coin_Bitcoin.csv")
netflix = pd.read_csv("data/netflix_titles.csv" , sep="|",index_col=0)
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
happy = pd.read_csv("data/world-happiness-report-2021.csv")

# %%
titanic.dtypes
# Out:
# pclass        int64
# survived      int64
# name         object
# sex          object
# age          object
# sibsp         int64
# parch         int64
# ticket       object
# fare         object
# cabin        object
# embarked     object
# boat         object
# body         object
# home.dest    object
# dtype: object

# %%
titanic["age"].replace(["?"],[None], inplace = True)

# %%
titanic.age.value_counts()
# Out:
# 24        47
# 22        43
# 21        41
# 30        40
# 18        39
#           ..
# 0.3333     1
# 22.5       1
# 70.5       1
# 0.6667     1
# 26.5       1
# Name: age, Length: 98, dtype: int64

# %%
titanic["age"]= titanic["age"].astype("float")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"] = titanic["sex"].astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   category
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: category(1), float64(1), int64(4), object(8)
# memory usage: 134.5+ KB

# %%
titanic["fare"].replace(["?"],[None], inplace = True)

# %%
titanic["fare"] = titanic["fare"].astype("float")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   category
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: category(1), float64(2), int64(4), object(7)
# memory usage: 134.5+ KB

# %%
stats = pd.read_csv("data/game_stats.csv")

# %%
stats
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN         NaN     NaN      NaN       NaN

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      6 non-null      object
#  1   league    4 non-null      object
#  2   points    5 non-null      float64
#  3   assists   2 non-null      float64
#  4   rebounds  4 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 408.0+ bytes

# %%
stats.isna()
# Out:
#     name  league  points  assists  rebounds
# 0  False   False   False    False     False
# 1  False    True   False     True     False
# 2  False   False    True     True      True
# 3  False   False   False     True     False
# 4  False    True   False     True      True
# 5  False   False   False    False     False
# 6   True    True    True     True      True

# %%
stats["assists"].dropna(inplace=True)

# %%
stats["assists"]
# Out:
# 0    5.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    8.0
# 6    NaN
# Name: assists, dtype: float64

# %%
stats.fillna("No value")
# Out:
#        name      league    points   assists  rebounds
# 0       bob         nba      22.0       5.0      10.0
# 1    jessie    No value      10.0  No value       2.0
# 2       stu  euroleague  No value  No value  No value
# 3   jackson         aba       9.0  No value       2.0
# 4  timothee    No value       8.0  No value  No value
# 5     steph         nba      49.0       8.0      10.0
# 6  No value    No value  No value  No value  No value

# %%
import pandas as pd
Billboard = pd.read_csv("data/billboard_charts.csv", parse_dates=["date"])
Billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure(figsize=(8,6))

# %%
Billboard
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
Billboard[Billboard["rank"]==1]["artist"].value_counts().head(10).plot(kind="barh", edgecolor = "black", linewidth =3)
plt.title("Artists With Most Weeks #1")
plt.xlabel("Weeks At #1")
# Out:
# Text(0.5, 0, 'Weeks At #1')

# %%
Billboard[Billboard["song"]=="Please Mr. Postman"]["artist"].value_counts().plot(kind="pie", colors = ["#6c5ce7","#00cec9", "#74b9ff"], explode = [0,0,0.1])

plt.title("Please Mr. Postman Version")
# Out:
# Text(0.5, 1.0, 'Please Mr. Postman Version')

# %%
plt.figure(figsize=(9,5))
BL =Billboard.song =="Blinding Lights"

Billboard[BL]["rank"].plot(color= '#a29bfe')
plt.gca().invert_yaxis()

# %%
plt.figure(figsize=(10,7))

# %%
Billboard = pd.read_csv("data/billboard_charts.csv", parse_dates=["date"])

df = Billboard[Billboard["date"].between("2016-12-25","2021-01-01")]
a = df[df["song"]=="All I Want For Christmas Is You"]
a["rank"].plot(label="All I Want For Christmas Is You")
b =df[df["song"]=="Rockin' Around The Christmas Tree"]
b["rank"].plot(label="Rockin' Around The Christmas Tree")
c =df[df["song"]=="Jingle Bell Rock"]
c["rank"].plot(label="Jingle Bell Rock")
plt.title("Christmas Song Among The Top 100")
plt.ylabel("Chart Rank")
plt.xlabel("Date")
plt.legend()

# %%
plt.figure(figsize=(14,8))
Billboard
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
Billboard[Billboard["song"]=="I'm Steppin' Out"]["artist"].value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %%
Billboard[Billboard["artist"]=="John Lennon"]["song"].value_counts("I'm Steppin' Out").plot(kind = "barh")

plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
Billboard[Billboard["artist"]=="Wings"].value_counts("songs").head(8).plot(kind="barh")
plt.subplot(2,2,2)
Billboard[Billboard["artist"]=="George Harrison"].value_counts()["song"].value_counts("I'm Steppin' Out").head(8).plot(kind="barh")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 5
#       3 plt.figure(figsize=(14,8))
#       4 plt.subplot(2,2,1)
# ----> 5 Billboard[Billboard["artist"]=="Wings"].value_counts("songs").head(8).plot(kind="barh")
#       6 plt.subplot(2,2,2)
#       7 Billboard[Billboard["artist"]=="George Harrison"].value_counts()["song"].value_counts("I'm Steppin' Out").head(8).plot(kind="barh")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7218, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7215 if subset is None:
#    7216     subset = self.columns.tolist()
# -> 7218 counts = self.groupby(subset, dropna=dropna).grouper.size()
#    7220 if sort:
#    7221     counts = counts.sort_values(ascending=ascending)
#
# ...

# %%
a= Billboard[Billboard["artist"]=="John Lennon"]["song"].value_counts(ascending = False).head(8)
b =Billboard[Billboard["artist"]=="Wings"]["song"].value_counts(ascending=False).head(8)
c =Billboard[Billboard["artist"]=="George Harrison"]["song"].value_counts(ascending=False).head(8)
d =Billboard[Billboard["artist"]=="Ringo Starr"]["song"].value_counts(ascending=False).head(8)
fig,axs = plt.subplots(2,2, figsize=(14,8))
plt.suptitle("Beatles Solo Songs (By Weeks On Charts", fontsize=20, )
a.plot(kind="barh", ax=axs[0][0], color="red")
b.plot(kind="barh", ax=axs[0][1], color="orange")
c.plot(kind="barh", ax=axs[1][0], color="blue")
d.plot(kind="barh", ax=axs[1][1],color="green")
plt.tight_layout()
